# %%
import pyautogui as py
import time as t
py.press('win')
t.sleep(0.5)
py.press('win')

# %% [markdown]
# Step 1 - Acess the industry system
# Step 2 - Login
# Step 3 - Dowload the data base
# Step 4 - Calculate indicators
# Step 5 - Send treated e-mail to other section ou diretory
#
# We are going to use:
# > pyautogui.click -> Click
# > pyautogui.press -> Press any key
# > pyautogui.hotkey -> Key's sets
# > py.autogui.write -> Write text
